# %% [markdown]
# ### Neuralink Challenge - Part 2
#
# - Download the validation dataset
# - See how the lookuptable does

# %%
# 1. Download challenge data
import requests, zipfile, io
res_zip = requests.get("https://content.neuralink.com/compression-challenge/data.zip")
zip_file = io.BytesIO(res_zip.content)
with zipfile.ZipFile(zip_file, 'r') as zip_ref:
    zip_ref.extractall("./")

# %%
# !ls data | wc -l
# Out:
# 743

# %%
import os
import hashlib
import wave
import numpy as np
import sqlite3

# Function to generate a truncated SHA-256 hash for a given segment
def generate_short_hash(segment, hash_size_bytes):
    hash_sha256 = hashlib.sha256(segment).digest()[:hash_size_bytes]  # Truncate SHA-256 hash
    return hash_sha256.hex()  # Convert to hex string

# Function to pack samples into appropriate byte segments
def pack_samples(samples, bit_depth):
    packed_value = np.uint64(0)
    for i, sample in enumerate(samples):
        packed_value |= np.uint64(sample) << np.uint64(bit_depth * (len(samples) - i - 1))
    num_bytes = (bit_depth * len(samples) + 7) // 8
    packed_bytes = packed_value.tobytes()[:num_bytes]  # Convert to bytes
    return packed_bytes

# Function to load the lookup table from the SQLite database
def load_lookup_table(db_name):
    conn = sqlite3.connect(db_name)
    c = conn.cursor()
    c.execute('SELECT hash, segment FROM lookup')
    lookup_table = {row[0]: row[1] for row in c.fetchall()}
    conn.close()
    return lookup_table

# Function to encode the wav data using the lookup table
def encode_wav_data_exhaustive(wav_data, bit_depth, segment_size, lookup_table, hash_size_bytes):
    encoded_data = []
    segment_found = []
    num_segments = len(wav_data) // segment_size

    for i in range(num_segments):
        samples = wav_data[i*segment_size:(i+1)*segment_size]
        segment = pack_samples(samples, bit_depth)
        hash_key = generate_short_hash(segment, hash_size_bytes)
        if hash_key in lookup_table:
            encoded_data.append(hash_key)
            segment_found.append(True)
        else:
            segment_found.append(False)

    return encoded_data, segment_found

# Function to calculate compression ratio
def calculate_compression_ratio(original_data, encoded_data, bit_depth, hash_size_bytes):
    original_size_bits = len(original_data) * bit_depth
    encoded_size_bits = len(encoded_data) * hash_size_bytes * 8  # Length of hash in bits
    compression_ratio = original_size_bits / encoded_size_bits
    return compression_ratio

# Function to process and score the uploaded WAV files
def process_uploaded_files(directory, bit_depth, segment_size, lookup_table, hash_size_bytes):
    file_scores = []
    for file_name in os.listdir(directory):
        if file_name.endswith('.wav'):
            file_path = os.path.join(directory, file_name)
            wav = wave.open(file_path, 'r')
            n_frames = wav.getnframes()
            frames = wav.readframes(n_frames)
            wav_data = np.frombuffer(frames, dtype=np.uint16)  # 16-bit samples packed in 16-bit space
            wav.close()

            encoded_data, segment_found = encode_wav_data_exhaustive(wav_data, bit_depth, segment_size, lookup_table, hash_size_bytes)
            compression_ratio = calculate_compression_ratio(wav_data, encoded_data, bit_depth, hash_size_bytes)
            percentage_found = sum(segment_found) / len(segment_found) * 100

            file_scores.append({
                'file_name': file_name,
                'compression_ratio': compression_ratio,
                'percentage_found': percentage_found
            })
            print(file_scores[-1])
    return file_scores

# Function to get the count of rows in the lookup table
def count_rows_in_lookup_table(db_name):
    conn = sqlite3.connect(db_name)
    c = conn.cursor()
    c.execute('SELECT COUNT(*) FROM lookup')
    count = c.fetchone()[0]
    conn.close()
    return count

# %%
# Parameters
bit_depth = 15
segment_size = 2   
hash_size_bytes = 3  # Truncated SHA-256 hash size in bytes (3 bytes = 24 bits)
db_name = 'nl_bit15_seg2_hash3.db'
directory = 'data'  # Directory containing the uploaded WAV files

# Load the lookup table
lookup_table = load_lookup_table(db_name)

# %%
# Count rows in the lookup table
row_count = count_rows_in_lookup_table(db_name)
print(f'Total number of rows in the lookup table: {row_count}')

# Process the uploaded files
file_scores_uploaded = process_uploaded_files(directory, bit_depth, segment_size, lookup_table, hash_size_bytes)

# Display the scores for uploaded files
for score in file_scores_uploaded:
    print(f"File: {score['file_name']}, Compression Ratio: {score['compression_ratio']:.2f}, Segments Found: {score['percentage_found']:.2f}%")
# Out:
# Total number of rows in the lookup table: 16777216
# {'file_name': '102b47d9-371e-412a-8995-0dc6115ab2bb.wav', 'compression_ratio': 1.2500126648969585, 'percentage_found': 100.0}
# {'file_name': '2eef5d4d-93d1-4c0e-9d23-0989abaa34d0.wav', 'compression_ratio': 1.2500126620745542, 'percentage_found': 100.0}
# {'file_name': 'fa2c5efb-cc0d-4292-ab99-91d345cf17d9.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '0458e9fc-6403-427e-afec-6a659104399a.wav', 'compression_ratio': 1.2500126636138915, 'percentage_found': 100.0}
# {'file_name': '30dee5fe-ded7-4978-9480-e40155e7b060.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '3953a230-d130-40e9-9dc4-068dda9bcef1.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '760ba446-aae7-4136-922c-9351c97504b8.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '2b1627e1-85a5-4155-ba52-4400e036b034.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '8559aba4-3f0b-45e3-add2-fcda2f9d586b.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '4036d06b-fc56-47ca-8a2f-d7e1c3f3d9a0.wav', 'compression_ratio': 1.2500126531025408, 'percentage_found': 100.0}
# {'file_name': '43758ea3-e5d2-4636-ad9c-ff5bfaa2914a.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '9397fd43-e0df-4c75-b27e-04c3ed2f0fb8.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '741e1978-11fb-4f4a-bf25-c43c239c226c.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'fea48b69-ccde-439e-9e7c-f06c72832c52.wav', 'compression_ratio': 1.2500126587406073, 'percentage_found': 100.0}
# {'file_name': 'bc9115d8-2363-4159-ae41-295a9129a9aa.wav', 'compression_ratio': 1.25001266797738, 'percentage_found': 100.0}
# {'file_name': '3ac7abb5-1e3e-4852-bfc8-e3f2875b765d.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '94c53803-f616-4c8e-b144-06d54ebfbfd1.wav', 'compression_ratio': 1.2500126636138915, 'percentage_found': 100.0}
# {'file_name': 'b8b26cb7-1bf1-4156-a51d-7994525690f2.wav', 'compression_ratio': 1.2500126595098238, 'percentage_found': 100.0}
# {'file_name': '2ed39ebf-8977-446b-a8c8-3e66bd4d4580.wav', 'compression_ratio': 1.2500126708024166, 'percentage_found': 100.0}
# {'file_name': '801e7cc4-db29-46e7-b866-b3e9b9cedb12.wav', 'compression_ratio': 1.2500126623310845, 'percentage_found': 100.0}
# {'file_name': 'aefab917-4a68-4d1a-ac3d-0c43da4270e6.wav', 'compression_ratio': 1.250012665153603, 'percentage_found': 100.0}
# {'file_name': '992741c5-8f08-4757-8e3f-01d3f1ca339d.wav', 'compression_ratio': 1.2500126618180345, 'percentage_found': 100.0}
# {'file_name': '54e7c135-fb37-454a-aaba-073bc67e5894.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'bf4510d0-4b67-47d9-af8d-0f4c81a532e6.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '17dddbf0-b621-49e0-adaa-85cefd4a9478.wav', 'compression_ratio': 1.250012661305026, 'percentage_found': 100.0}
# {'file_name': '54c317db-4533-40d6-bef7-50b0bd4ba6eb.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '99fac516-3ece-48a6-872d-162348c89a86.wav', 'compression_ratio': 1.2500126595098238, 'percentage_found': 100.0}
# {'file_name': '0e6689fb-4020-4972-8c33-d563b0ed4690.wav', 'compression_ratio': 1.2500126669504064, 'percentage_found': 100.0}
# {'file_name': '5cef007b-2979-46be-a3f5-a1efab9fd763.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'ce96a016-f36c-446c-8ab0-cbd10b74684a.wav', 'compression_ratio': 1.2500126607920592, 'percentage_found': 100.0}
# {'file_name': 'd3a3ed97-626d-49c4-a253-b6e4ed73f260.wav', 'compression_ratio': 1.2500126628441761, 'percentage_found': 100.0}
# {'file_name': '0eab843a-5e03-469a-aafc-6d5d3af44714.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '3daf2025-0d64-4e57-b27c-0f922bbcea9c.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '925d2ac5-270b-4470-8950-88cb6b08fcf9.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '0b049a37-dc68-42f6-bbe5-d7d1cd699ccb.wav', 'compression_ratio': 1.2500126702886798, 'percentage_found': 100.0}
# {'file_name': '52d00faf-9be7-4254-917c-8d4a3197a5db.wav', 'compression_ratio': 1.2500125855819573, 'percentage_found': 100.0}
# {'file_name': '4b914037-3c4a-4b7f-b680-a3e642e52389.wav', 'compression_ratio': 1.2500126584842224, 'percentage_found': 100.0}
# {'file_name': 'e97a68d2-5d2a-471f-bd22-a3fb8537c32d.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '5180ddb3-fc5d-4924-9e94-3d1228c17e43.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'aa3e9623-8662-4667-8157-e1dfcc680513.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'be8571fe-8f36-4eb2-ab23-e374dea1133d.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'bd009dca-f25e-49bd-852f-da52c2139281.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'e32ab322-a34e-4348-ac9a-005861378f5d.wav', 'compression_ratio': 1.2500126646403242, 'percentage_found': 100.0}
# {'file_name': '06bcf5af-fb5a-40a1-bf82-2499d8478c28.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '9ff08c78-1f8b-43cb-94af-12bdd652b6a0.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'ab910051-02db-4931-8eae-dd1306f1cf0d.wav', 'compression_ratio': 1.25001266797738, 'percentage_found': 100.0}
# {'file_name': 'd30c7d18-03e5-4851-a0ea-493d0ad5d877.wav', 'compression_ratio': 1.2500126648969585, 'percentage_found': 100.0}
# {'file_name': '4f9fb4d9-50ea-432f-ac30-9f597d6178df.wav', 'compression_ratio': 1.2500126584842224, 'percentage_found': 100.0}
# {'file_name': '036b3893-f89c-4010-85b0-7e8089326d45.wav', 'compression_ratio': 1.2500126646403242, 'percentage_found': 100.0}
# {'file_name': '68c55c27-86d1-4ab1-8acb-d7b9d83bc474.wav', 'compression_ratio': 1.2500126656669233, 'percentage_found': 100.0}
# {'file_name': '583a820c-0ce6-44b0-8100-fe353ce6d3e1.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '28cd0f1e-bc90-46ac-8f09-56fe0a7a7937.wav', 'compression_ratio': 1.250012657971484, 'percentage_found': 100.0}
# {'file_name': '3e2b974a-3e13-48f3-b2f7-40a0c18c838f.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'd145ea64-c55c-4dda-b4eb-82120b3b8703.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '833d25d9-6cb0-46bc-9eb8-2301dd91527a.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '957551b0-1365-4536-8aba-90d35eefd5ee.wav', 'compression_ratio': 1.2500126625876251, 'percentage_found': 100.0}
# {'file_name': '4c949895-0947-455b-803d-74102b41e754.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'daab98b7-f874-4a9b-9a82-1458d2e1386b.wav', 'compression_ratio': 1.2500126661802853, 'percentage_found': 100.0}
# {'file_name': '34b4f683-c0d2-4c56-8ddd-9b9a9f0a0d79.wav', 'compression_ratio': 1.2500126636138915, 'percentage_found': 100.0}
# {'file_name': 'f49e8460-52d7-44da-a876-fc9cbc4b3033.wav', 'compression_ratio': 1.250012657971484, 'percentage_found': 100.0}
# {'file_name': 'e1ef09f7-f8c6-4b73-8c5c-e39fc26fce4e.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'deaec89a-aa07-4f8a-a017-89443c488ef0.wav', 'compression_ratio': 1.2500126751708613, 'percentage_found': 100.0}
# {'file_name': '214224f7-01e9-4b3a-9e12-55fc5706ea41.wav', 'compression_ratio': 1.250012661305026, 'percentage_found': 100.0}
# {'file_name': '9d3e8196-799c-4404-8d59-af61101299f5.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'ff8b34c6-6b6c-4f74-957c-299954a1b247.wav', 'compression_ratio': 1.2500126584842224, 'percentage_found': 100.0}
# {'file_name': '8895b3c3-6934-442a-ba91-e4c0201c45a2.wav', 'compression_ratio': 1.2500126247323557, 'percentage_found': 100.0}
# {'file_name': 'a90f5eca-fdbe-4a21-94bd-c4c7f32fe365.wav', 'compression_ratio': 1.250012667207134, 'percentage_found': 100.0}
# {'file_name': '7f358ab2-6356-4a0e-a4ca-127a43e0ded5.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'db1a562f-d9ca-433a-9375-4203ee149d3e.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '497c142c-fa79-4261-95a6-447a1c8eab31.wav', 'compression_ratio': 1.2500126254974446, 'percentage_found': 100.0}
# {'file_name': '1c286f7b-612f-4883-934a-186859617a04.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '9f482d55-d8ad-4c9b-b73b-1c66e061d7ab.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '40113ce6-baad-42dc-ba65-2203f5a8bf60.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'd5080a60-fd1c-4e4b-82ba-17efe58d4c81.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '5bfa0a02-0627-4ad8-a030-ac44924fe784.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '14ec91ca-9d79-448e-a760-7ccbd2099820.wav', 'compression_ratio': 1.2500126564335183, 'percentage_found': 100.0}
# {'file_name': '66811b61-6744-4a77-bfea-4ed03c915224.wav', 'compression_ratio': 1.2500126623310845, 'percentage_found': 100.0}
# {'file_name': '6a018865-7f65-4890-8216-cc50de8a588b.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '3c1ab183-52ac-42fd-8cd1-6b2456ee6280.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '59bb0d7e-eb5f-4d56-8a26-21fd7809db2a.wav', 'compression_ratio': 1.2500126648969585, 'percentage_found': 100.0}
# {'file_name': '658bf659-6c2e-4af6-b218-36276437742a.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '18938028-59c1-401f-9aca-ae836d963335.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'd449b8dc-abf8-426a-af77-8ad6b5d951be.wav', 'compression_ratio': 1.2500126620745542, 'percentage_found': 100.0}
# {'file_name': 'd2fae317-4f64-4ee0-ba3b-ea2ff966ca50.wav', 'compression_ratio': 1.2500126636138915, 'percentage_found': 100.0}
# {'file_name': 'eee9bdc4-317b-43a6-aa96-9cb2e2912bd1.wav', 'compression_ratio': 1.2500126605355912, 'percentage_found': 100.0}
# {'file_name': 'a0424451-3231-4fda-9c65-5ef675c03b0c.wav', 'compression_ratio': 1.2500126618180345, 'percentage_found': 100.0}
# {'file_name': '7fa8fc6c-a731-4903-8273-efe57067cf3a.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'b474c204-4ac7-4976-9940-9733868a6d13.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '72442cc8-c342-4339-b933-7d2ca5cc68b9.wav', 'compression_ratio': 1.2500126587406073, 'percentage_found': 100.0}
# {'file_name': '0d4d9e06-e93c-4bb9-9ac0-517084f7ab18.wav', 'compression_ratio': 1.2500126288139017, 'percentage_found': 100.0}
# {'file_name': 'eae04418-82da-40a0-89ba-ffd44b975295.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'fb1c5539-8ccb-462c-aef5-21178d31aab7.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '1fb45d27-5f79-4e5f-9b4f-11adf77bd495.wav', 'compression_ratio': 1.2500126587406073, 'percentage_found': 100.0}
# {'file_name': 'a5586c15-fe4a-4126-ac5c-fffabc20bd74.wav', 'compression_ratio': 1.25001265976625, 'percentage_found': 100.0}
# {'file_name': 'd6bc40d5-32ba-4c28-bcd5-3542ff9445b4.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '85c7805b-4884-4880-9fac-bed80f2fd142.wav', 'compression_ratio': 1.250012547177387, 'percentage_found': 100.0}
# {'file_name': '31fe1b06-79fa-41b2-9715-c4224d48fee8.wav', 'compression_ratio': 1.250012660279134, 'percentage_found': 100.0}
# {'file_name': '35c16396-67a4-4fba-bde1-5f8722b12ddd.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '7046ebd2-f362-4fff-a3f8-5e158dfbf698.wav', 'compression_ratio': 1.2500126592534078, 'percentage_found': 100.0}
# {'file_name': 'a05767ff-af49-4cae-852e-c463a09a85c8.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '69913125-382c-47d3-b5fa-ccb015f1a20a.wav', 'compression_ratio': 1.2500126692613314, 'percentage_found': 100.0}
# {'file_name': 'ddfc0897-f917-47b6-b998-61b49f1eec6a.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '20824c82-39cf-47f1-a71a-9d61e0f3601a.wav', 'compression_ratio': 1.250012665923599, 'percentage_found': 100.0}
# {'file_name': 'a25eb39c-58ea-4466-8c47-1ec152ecee4e.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '85ebe8f7-202a-4357-a296-11204a297936.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'd68cbb41-c533-425c-9dc1-5a3f1cdc63e4.wav', 'compression_ratio': 1.2500126592534078, 'percentage_found': 100.0}
# {'file_name': '178943a5-c3b3-48f6-9da6-c4b8047c6bf2.wav', 'compression_ratio': 1.250012666693689, 'percentage_found': 100.0}
# {'file_name': 'b876af63-bbdc-48b2-bb75-6acfe53f911b.wav', 'compression_ratio': 1.2500126221827288, 'percentage_found': 100.0}
# {'file_name': '4281bfb9-ee31-49a7-8e1f-393b469b1a6c.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '2dab120f-5bc3-4c75-b49f-2a28fbd3a05a.wav', 'compression_ratio': 1.2500126178507258, 'percentage_found': 100.0}
# {'file_name': '42b04847-a231-4e4f-adc8-506e6f7e30ad.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'f30afd56-4ff8-47c3-893f-dfd448035c0f.wav', 'compression_ratio': 1.250012670031827, 'percentage_found': 100.0}
# {'file_name': 'f654945a-df35-44ed-aa41-47bc44a361a7.wav', 'compression_ratio': 1.2500126275381351, 'percentage_found': 100.0}
# {'file_name': '8f2d6a00-8a24-4ab1-af57-56cf676566ed.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '82c00bf9-2270-4983-a505-9f7a39d5cdab.wav', 'compression_ratio': 1.2500126607920592, 'percentage_found': 100.0}
# {'file_name': '83d33cbd-1fd4-4fcd-b9a0-74d208ab8e97.wav', 'compression_ratio': 1.2500126610485374, 'percentage_found': 100.0}
# {'file_name': '572159e4-9c20-4dd8-a050-33e518102fde.wav', 'compression_ratio': 1.2500126607920592, 'percentage_found': 100.0}
# {'file_name': 'e4409881-5c55-40aa-9849-3f29c1484880.wav', 'compression_ratio': 1.25001266797738, 'percentage_found': 100.0}
# {'file_name': 'c94a64a6-8631-4e8a-a42e-6754a62df32b.wav', 'compression_ratio': 1.2500126254974446, 'percentage_found': 100.0}
# {'file_name': '03f3c8e1-df39-4f6e-906f-ba2c6b28e2b8.wav', 'compression_ratio': 1.2500126715730997, 'percentage_found': 100.0}
# {'file_name': 'c50256f6-cffc-4e1d-977c-473c32bc52bf.wav', 'compression_ratio': 1.2500126254974446, 'percentage_found': 100.0}
# {'file_name': '33a9bb59-ce20-4ed9-89ac-7946b67d92a8.wav', 'compression_ratio': 1.250012628048411, 'percentage_found': 100.0}
# {'file_name': 'e9ceeddd-b7e3-4d0f-a770-33886b99757b.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '99b5a310-c47c-498d-8d61-c8545ab15fac.wav', 'compression_ratio': 1.2500126531025408, 'percentage_found': 100.0}
# {'file_name': '2a42a79d-af6e-4d60-bf4f-672e99dd90d8.wav', 'compression_ratio': 1.2500126605355912, 'percentage_found': 100.0}
# {'file_name': '690b7f03-ae93-47e4-a361-5b99335cf939.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '7c993322-c1bb-49b2-a676-f6589d976ec0.wav', 'compression_ratio': 1.250012657971484, 'percentage_found': 100.0}
# {'file_name': '3688abd7-707b-4379-8dec-ccc0b42159d6.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '47bcd211-fdd3-4b3d-81bb-72595dac9dc2.wav', 'compression_ratio': 1.2500126620745542, 'percentage_found': 100.0}
# {'file_name': '5e4ba99a-cc6d-41f6-b1da-a53593522574.wav', 'compression_ratio': 1.250012660279134, 'percentage_found': 100.0}
# {'file_name': '460915c7-7a07-4feb-909f-e7bb1e4806c0.wav', 'compression_ratio': 1.2500126646403242, 'percentage_found': 100.0}
# {'file_name': 'd94b22d0-1a8b-40b0-ac37-0995d884da0d.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '4fdc6242-e58b-4687-bd69-94e4aa83db0f.wav', 'compression_ratio': 1.250012661561525, 'percentage_found': 100.0}
# {'file_name': 'c4f4e43d-a873-4629-a65b-448a031c6df2.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'dcc8d8de-081e-4d2a-a713-875a3e794de3.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'a8c92d53-2167-4bf8-ab8c-1a9bc9c30eaf.wav', 'compression_ratio': 1.250012666436982, 'percentage_found': 100.0}
# {'file_name': '4e712e8f-d37e-424b-97c9-7668064ffca9.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '24bc203a-0fe0-4b44-8c9b-982404799344.wav', 'compression_ratio': 1.250012663870484, 'percentage_found': 100.0}
# {'file_name': 'f8b28d7c-4d7d-4326-984d-4edb95e6412b.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '341618b8-0266-4e52-82eb-600096c3023c.wav', 'compression_ratio': 1.250012664127087, 'percentage_found': 100.0}
# {'file_name': 'ae03cfaa-2441-45f4-8b79-b85b5238274f.wav', 'compression_ratio': 1.2500126247323557, 'percentage_found': 100.0}
# {'file_name': '9123d8d8-0094-4896-a17a-27749073eb3a.wav', 'compression_ratio': 1.250012675942076, 'percentage_found': 100.0}
# {'file_name': 'a8b3d81c-6b11-4ccd-ba46-49583be0f567.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '3830d316-1af4-4496-be1a-553298450516.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '9a2c6ac3-0bec-4ce1-b4c9-c6d80bd9f521.wav', 'compression_ratio': 1.2500126643837004, 'percentage_found': 100.0}
# {'file_name': '0c3f4ca2-459d-4643-9b7b-a2c7ec378172.wav', 'compression_ratio': 1.2500126595098238, 'percentage_found': 100.0}
# {'file_name': '24104b38-32fb-486a-a0a9-a964d6699b9d.wav', 'compression_ratio': 1.2500126643837004, 'percentage_found': 100.0}
# {'file_name': '5bf48169-b0bb-4aed-b870-928b1ec009bf.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '2c96ae4e-9d50-4d68-8756-a27bfe524812.wav', 'compression_ratio': 1.2500126226925719, 'percentage_found': 100.0}
# {'file_name': '414b9d5a-df01-49ea-a0f0-5cc297041bb9.wav', 'compression_ratio': 1.2500126628441761, 'percentage_found': 100.0}
# {'file_name': '5f3e80dc-6e4f-4ced-a670-618955fc06ae.wav', 'compression_ratio': 1.25001265976625, 'percentage_found': 100.0}
# {'file_name': '3eea00c0-8df7-41cd-9bfb-c27d42156021.wav', 'compression_ratio': 1.250012663870484, 'percentage_found': 100.0}
# {'file_name': '64b2e68d-5fb4-4a44-82eb-5734a415e978.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'cf3f227f-3354-49a3-b78f-b29dd60b2961.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '970e1a07-8c67-49a4-b437-33ea735dd5eb.wav', 'compression_ratio': 1.2500126610485374, 'percentage_found': 100.0}
# {'file_name': '930e4b17-6ecb-419f-8e14-65c547424eaf.wav', 'compression_ratio': 1.2500126234574136, 'percentage_found': 100.0}
# {'file_name': '663e167d-03e3-47ae-940b-5862c64e8a09.wav', 'compression_ratio': 1.2500126610485374, 'percentage_found': 100.0}
# {'file_name': '2908e5a8-7668-43ed-a5be-caa2822f52ba.wav', 'compression_ratio': 1.250012666436982, 'percentage_found': 100.0}
# {'file_name': 'd1768885-813b-42b4-9b90-150a8b47e1db.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'b552734f-6d92-4b26-a17b-ddddd456ab94.wav', 'compression_ratio': 1.250012665923599, 'percentage_found': 100.0}
# {'file_name': '759b65fe-ad0c-43c7-a1a9-9feeeba38347.wav', 'compression_ratio': 1.250012660279134, 'percentage_found': 100.0}
# {'file_name': 'b212f1f3-ce69-4104-b397-e26ba470612b.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'f5bed109-d390-47d8-ad66-f850d84e9e8f.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '25f79305-22a6-49f2-8c9b-0a0e9ef5d539.wav', 'compression_ratio': 1.2500126618180345, 'percentage_found': 100.0}
# {'file_name': 'ba156869-b73d-4263-9879-c6f8799cc975.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '3864cbab-5e6d-40b1-bb5e-c130319c36a5.wav', 'compression_ratio': 1.2500126607920592, 'percentage_found': 100.0}
# {'file_name': '051eee27-45b5-4bbe-812e-85e046ba043a.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '23b3073f-3fa5-481a-a950-27df33e4d878.wav', 'compression_ratio': 1.2500126623310845, 'percentage_found': 100.0}
# {'file_name': '43619ffb-79ef-4d60-aaa7-928b2a143e51.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '85d726b5-89b8-4e59-8e9c-e1a2ca308d71.wav', 'compression_ratio': 1.2500126633573092, 'percentage_found': 100.0}
# {'file_name': 'f920dc45-1cd5-4dd8-9f34-ed20faaabf71.wav', 'compression_ratio': 1.2500126631007376, 'percentage_found': 100.0}
# {'file_name': '5b4d164d-2188-46b1-87d0-d14edf796a3b.wav', 'compression_ratio': 1.2500126620745542, 'percentage_found': 100.0}
# {'file_name': '3f203ef0-d1e3-4a88-859e-40b37287000a.wav', 'compression_ratio': 1.2500126692613314, 'percentage_found': 100.0}
# {'file_name': 'd9a6fb80-d455-4efc-b4ca-7c3c02edac75.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'b00473d5-2043-4af7-ac66-d44917da73d2.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '254000d9-9fd8-43a0-a561-c81a6feee649.wav', 'compression_ratio': 1.250012661305026, 'percentage_found': 100.0}
# {'file_name': '561fb19f-7fee-4994-9baf-d9aca4069498.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '6fa836a3-a161-4ba6-8b88-08e5c6b466e2.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'd66445a3-fc1f-479f-a4af-122b78080f76.wav', 'compression_ratio': 1.2500126584842224, 'percentage_found': 100.0}
# {'file_name': '9b06f0d3-83f7-4fd0-9f03-34e0c10560a4.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '80ffe67b-24d9-44f8-b3fc-41c22b55d710.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '429f76f3-c417-457b-828a-a7915f60e0e7.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '06f283af-9867-4aa7-b97c-a60c6f795d17.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '006c6dd6-d91e-419c-9836-c3f320da4f25.wav', 'compression_ratio': 1.2500126620745542, 'percentage_found': 100.0}
# {'file_name': 'edaf84eb-3dc4-42f9-a77c-3ea691b66c1e.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '08e1153c-1675-40f3-864d-5e93eb4c2134.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '80fb272f-19d9-4a53-91a7-9f11098e1ded.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '8b4c8568-4839-4096-812b-73d2ba6e5b64.wav', 'compression_ratio': 1.2500125855819573, 'percentage_found': 100.0}
# {'file_name': '0ff32e7e-47c6-44b4-821a-6ba3f5c6c00b.wav', 'compression_ratio': 1.2500126536148848, 'percentage_found': 100.0}
# {'file_name': '0ab237b7-fb12-4687-afed-8d1e2070d621.wav', 'compression_ratio': 1.2500126595098238, 'percentage_found': 100.0}
# {'file_name': '82dba97c-c0b2-421b-b689-5c583f4778bb.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '9b7e86af-90c1-4297-aca8-2c8c7ea115f2.wav', 'compression_ratio': 1.2500126574587873, 'percentage_found': 100.0}
# {'file_name': '91efca4b-4929-4404-96ef-0a0b165d0ca5.wav', 'compression_ratio': 1.25001266797738, 'percentage_found': 100.0}
# {'file_name': 'd810d805-6924-4c5d-a38c-179214bd1e6a.wav', 'compression_ratio': 1.2500126257524948, 'percentage_found': 100.0}
# {'file_name': '8b243863-b6f8-43d1-bdc9-05924e82e152.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '9f28ad19-763a-4d25-b9fe-72d86b9d7fb6.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '117d7c23-4a4f-40b9-83e4-b5cd26ba6e97.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'b033937f-7e13-4a08-ae12-b83eb8e380e9.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'b64dd1e7-bec9-406e-909f-477da078965d.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '62c0e50b-2bf6-4ecf-85b6-6ebf36e564b5.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '5b19872b-2741-448f-b07a-d50d47509308.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'b516f828-6299-4be9-9a95-908b81095472.wav', 'compression_ratio': 1.250012667720621, 'percentage_found': 100.0}
# {'file_name': '74570b9d-d470-43ca-9771-5255adcfc8f4.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '06469380-cf24-4288-80bd-f78b9499ef3f.wav', 'compression_ratio': 1.25001265976625, 'percentage_found': 100.0}
# {'file_name': '6e91dd23-2f15-48e2-b5d1-1d72ee8d1f3c.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '31827810-e5d6-4647-8d72-8d0fe63ce83e.wav', 'compression_ratio': 1.25001265668982, 'percentage_found': 100.0}
# {'file_name': '2458a5be-c274-4fd3-82f6-4617caeaeb14.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '6a8f6a6e-48ce-4e1f-a22e-8237c4123323.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'bdbf74d4-fdfb-4d7a-b7f1-3bdcea62a8fc.wav', 'compression_ratio': 1.2500126648969585, 'percentage_found': 100.0}
# {'file_name': 'd262b7b5-5b79-4743-95a8-cefe85c06eab.wav', 'compression_ratio': 1.2500126605355912, 'percentage_found': 100.0}
# {'file_name': '1243dd43-3312-4b5b-8bcb-d998c4da2241.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'ddc6ec5c-8c6c-41ab-8bdb-e54930f84b0a.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'baf70ec4-328d-43c8-84a3-402094fff54a.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '4fd22ca4-99f3-4b33-9510-ba32d4a2f46f.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '1cf09880-83f7-4558-9a18-2b843408d622.wav', 'compression_ratio': 1.2500126584842224, 'percentage_found': 100.0}
# {'file_name': '227ddafb-452b-4255-8ace-433872cac40b.wav', 'compression_ratio': 1.2500126656669233, 'percentage_found': 100.0}
# {'file_name': '7ae7cda8-d030-4ceb-9a6a-ad5e1222ccd8.wav', 'compression_ratio': 1.2500126582278481, 'percentage_found': 100.0}
# {'file_name': '832c946a-e7bf-4b06-9020-1f5cf16ffb66.wav', 'compression_ratio': 1.2500126214180416, 'percentage_found': 100.0}
# {'file_name': '25ad5045-179a-4b20-a0a6-9d3ab35c476c.wav', 'compression_ratio': 1.250012665923599, 'percentage_found': 100.0}
# {'file_name': '7434e3e9-74dd-4dc6-a586-4d38280caca6.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '55b06e93-7249-45c1-a567-77ca8324d080.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '2b3fa930-47b0-4358-8971-3dcd9c8fd0c1.wav', 'compression_ratio': 1.2500126620745542, 'percentage_found': 100.0}
# {'file_name': '64d5c24b-2e31-41ba-afba-5bc85d9b43cc.wav', 'compression_ratio': 1.250012665410258, 'percentage_found': 100.0}
# {'file_name': '4b96ef39-9af5-4fe7-82c7-658f9ed956e9.wav', 'compression_ratio': 1.2500126610485374, 'percentage_found': 100.0}
# {'file_name': '999d0f90-82a1-4185-85e6-33c7014b585a.wav', 'compression_ratio': 1.2500126623310845, 'percentage_found': 100.0}
# {'file_name': '3191b268-0a7a-46d5-a801-0da511379469.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'aaafe57f-3851-405e-88d1-89ad577086f3.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'cbf01787-9e7c-4705-930b-53769a9d92b0.wav', 'compression_ratio': 1.2500126584842224, 'percentage_found': 100.0}
# {'file_name': '00d4f842-fc92-45f5-8cae-3effdc2245f5.wav', 'compression_ratio': 1.250012666436982, 'percentage_found': 100.0}
# {'file_name': '030ac074-4f10-4260-b41c-253cf3bc88e0.wav', 'compression_ratio': 1.2500126247323557, 'percentage_found': 100.0}
# {'file_name': '803d9d3f-d4da-43c1-b4dd-b9bc17d51b3e.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'd3f365c9-b89d-4834-86b6-e9aa34e85e0c.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '6ea9f572-2612-4be6-981a-757b4c6f3af6.wav', 'compression_ratio': 1.2500126551521655, 'percentage_found': 100.0}
# {'file_name': 'aeed8d2c-e2bf-4618-81b6-6d744db135b4.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'd543cebf-3aa4-4f81-810c-0869a84b9899.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '5d57241d-83db-444f-ad3e-4ccee3f23373.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'd68a7404-d436-4b22-b522-93ff403c6ece.wav', 'compression_ratio': 1.250012666693689, 'percentage_found': 100.0}
# {'file_name': 'f567ddab-9f82-4e03-88b9-2a8af1dbcfde.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'd40b3d0a-21fd-42a8-a0bd-a38a431e9401.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'a0a52a27-69b6-4783-b0b9-6636d9626045.wav', 'compression_ratio': 1.2500126674638723, 'percentage_found': 100.0}
# {'file_name': 'd46140f2-956a-44cf-b95c-f5f0677313ae.wav', 'compression_ratio': 1.2500126610485374, 'percentage_found': 100.0}
# {'file_name': '72911a4e-dd47-4065-a940-8dfee619066c.wav', 'compression_ratio': 1.250012664127087, 'percentage_found': 100.0}
# {'file_name': '0847e903-ffad-4196-86c3-298e0719e4fa.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'd6c94651-3e56-4126-8a25-c76b0742203c.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '8c3841db-777f-4fae-8cdc-6b60bfbe27bb.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'fa9217f9-54aa-405b-b15f-7ad24b69fe09.wav', 'compression_ratio': 1.2500126221827288, 'percentage_found': 100.0}
# {'file_name': '6df93e0a-9710-4099-9346-584c1e0ba191.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '9948c725-70ba-4a73-a7f3-dac69ac76b76.wav', 'compression_ratio': 1.2500126237123814, 'percentage_found': 100.0}
# {'file_name': '662a83b5-33f4-4a49-a861-39a24a0612e6.wav', 'compression_ratio': 1.250012673885712, 'percentage_found': 100.0}
# {'file_name': '5e1df97c-6eee-4e6c-9ea5-0e5d228f3ea2.wav', 'compression_ratio': 1.2500126605355912, 'percentage_found': 100.0}
# {'file_name': '79c04d9b-f39c-42ed-877f-e78d9986105e.wav', 'compression_ratio': 1.2500126584842224, 'percentage_found': 100.0}
# {'file_name': 'bcc36cfb-115f-40a6-97c3-5eb67b0e1198.wav', 'compression_ratio': 1.2500126610485374, 'percentage_found': 100.0}
# {'file_name': '26205e98-f416-4cf4-81c3-adcb646fffb8.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '6dc3a8b6-961d-439b-a763-21c1a9998af3.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'e79302e4-7e71-4769-a927-2e6976442f55.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'c88d7db7-ecd2-4993-bb50-f1902af6e021.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '7cdd94af-8532-4a4d-9b14-3a9a7e986932.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '84e2a6ed-2740-40c7-8bc8-1f416a335d3b.wav', 'compression_ratio': 1.25001265976625, 'percentage_found': 100.0}
# {'file_name': '54c6a6ff-c5e1-4aee-a8e9-3f47401459f9.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '93b368d8-e5e0-4f7d-a68b-f4127b39c36b.wav', 'compression_ratio': 1.2500126203986026, 'percentage_found': 100.0}
# {'file_name': 'b0b12199-956f-4089-87a0-b89fef92d7d8.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '6b3280a8-ef75-4bfc-b545-870dec21a776.wav', 'compression_ratio': 1.250012665153603, 'percentage_found': 100.0}
# {'file_name': '4fd5d61c-1484-441c-8c3c-b5669d0e2292.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'fd683360-e024-4c66-ac71-97fbf6989dfc.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '58c8f69c-0a56-4579-bf29-c888362d855e.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '5c3164e9-2c4c-4226-99a0-d346718ace24.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '1b517404-93f9-409f-9dca-18ff2e6d9885.wav', 'compression_ratio': 1.2500126572024546, 'percentage_found': 100.0}
# {'file_name': '4876213e-ca0c-4b88-9016-800da79fd8f9.wav', 'compression_ratio': 1.250012675942076, 'percentage_found': 100.0}
# {'file_name': 'ce441d17-f005-413d-9e30-e631df26e53c.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '6ac7e280-8705-4b5b-9cee-ae076d052c1c.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'debdca70-52be-4fcb-9bfe-41cf69d2bc04.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'f1b1fc43-c4b1-403f-a8f3-25e0ec5f0093.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '8f01091f-f602-4391-a3de-a59bcf4e5847.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'a4e9a288-6308-483b-b6b8-e242de021272.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'd118281d-126f-4c4c-8fbb-6277ddf0aa4e.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'c07fa32b-f809-4f58-96dd-4e6089db94c6.wav', 'compression_ratio': 1.2500126620745542, 'percentage_found': 100.0}
# {'file_name': 'a811e693-aa09-4f28-951a-a64007d87baf.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '65251536-2706-40ee-83f4-65bc2a4dd0c9.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'bbad0173-3dcc-4567-ba3d-9ece2be70762.wav', 'compression_ratio': 1.250012664127087, 'percentage_found': 100.0}
# {'file_name': 'acbe8f00-dbe6-4353-a657-60adbe50a996.wav', 'compression_ratio': 1.2500126623310845, 'percentage_found': 100.0}
# {'file_name': '64058005-fd38-44ab-90aa-2b96fbc8bc76.wav', 'compression_ratio': 1.2500126674638723, 'percentage_found': 100.0}
# {'file_name': '1d21e7b7-5eb9-42b0-a576-d6dff31c001c.wav', 'compression_ratio': 1.2500126607920592, 'percentage_found': 100.0}
# {'file_name': '7e872649-2464-42ab-b751-af26a9429998.wav', 'compression_ratio': 1.2500126636138915, 'percentage_found': 100.0}
# {'file_name': 'feb70e8b-cf42-4c8b-ab9b-121e78998876.wav', 'compression_ratio': 1.250012661561525, 'percentage_found': 100.0}
# {'file_name': '0161dc01-ec36-4fe7-bbbc-1801586d28f7.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '26b2ca81-4399-4fa9-80e0-7fbb3988d784.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '388f0aab-1b82-4efa-83fd-a1f9d7440f70.wav', 'compression_ratio': 1.2500126769705082, 'percentage_found': 100.0}
# {'file_name': '9104d161-bf37-4164-af00-9af711a7500c.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'fefade45-a947-43b3-8b55-578b1c7c74ed.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'b7684435-eaf2-43ee-8912-2769e8d117d2.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'ceaa4976-a8b5-4736-88f1-17234842235c.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '7c12e85e-e5e9-49f5-82a6-e024d9ef1374.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'a521dc4c-ec2e-4613-837b-b35b994aad56.wav', 'compression_ratio': 1.250012667207134, 'percentage_found': 100.0}
# {'file_name': 'f5807fdb-98c1-4203-9742-c3a975b77ce6.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '0d7c2b8b-8ae4-4288-9720-8402d737c1b5.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'cf0b1fe7-c4d8-49dd-be40-2d2abbb5c1e0.wav', 'compression_ratio': 1.2500126262626263, 'percentage_found': 100.0}
# {'file_name': '2a661247-dfa0-42b2-9d0a-a5925ac8735a.wav', 'compression_ratio': 1.250012667720621, 'percentage_found': 100.0}
# {'file_name': '4ebd6952-60ae-448f-bbfa-539e130ba3b2.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'c0802070-70d2-4475-b808-66cfd408a22a.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '55fa663c-b545-4ede-8c73-acf1a7ba8c20.wav', 'compression_ratio': 1.250012657971484, 'percentage_found': 100.0}
# {'file_name': '4a0bf089-ab79-43e0-9a3d-caa48ad8b0af.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '998d4e1e-64c6-4e50-8c40-195ebe6951f4.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '799e7b1b-7c1d-4c67-a115-6551ade2cdaf.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '3179ab62-2b34-456b-91b5-d9a99d4c78e8.wav', 'compression_ratio': 1.2500126643837004, 'percentage_found': 100.0}
# {'file_name': 'ec3e1856-6910-4180-aaa4-6bb5365300a3.wav', 'compression_ratio': 1.2500126656669233, 'percentage_found': 100.0}
# {'file_name': '4c769ab2-eb5f-4cb8-9ae8-fe0457335cbe.wav', 'compression_ratio': 1.2500126584842224, 'percentage_found': 100.0}
# {'file_name': 'cc58a08c-5d9a-4f33-a19e-b2bd50ce56b5.wav', 'compression_ratio': 1.250012666693689, 'percentage_found': 100.0}
# {'file_name': '9496c16e-a591-4a78-870f-744822a847e6.wav', 'compression_ratio': 1.2500125504528203, 'percentage_found': 100.0}
# {'file_name': 'e2346160-fb7c-4dbc-a6ed-5835fd1b098c.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '44a67074-6d06-4087-9ec3-a5de75016aa8.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '9a92f7a6-c5ea-4416-a61e-a330fc25a887.wav', 'compression_ratio': 1.250012667720621, 'percentage_found': 100.0}
# {'file_name': 'acb24204-d3e1-4c59-9fe5-6b893491a189.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '85a4c4d4-ebe4-449a-a7d1-572da07a3631.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '5edf2908-7483-444c-b93b-9ae9beb155b1.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '189fd9b7-d128-4d50-8448-e7d9a019c4f2.wav', 'compression_ratio': 1.2500126692613314, 'percentage_found': 100.0}
# {'file_name': 'dd615d4f-50d1-4f4a-985b-109765a6c673.wav', 'compression_ratio': 1.2500126605355912, 'percentage_found': 100.0}
# {'file_name': '6ce74c98-7bd8-4469-8866-63d846be6357.wav', 'compression_ratio': 1.250012670031827, 'percentage_found': 100.0}
# {'file_name': '751d7d4b-95b1-45d6-9c95-a145c8c8d13a.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '7d95d4cc-360b-4e1c-a775-63b9e45aa0bc.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '6f3f218f-5bbf-4173-a9c7-388e8c101d8e.wav', 'compression_ratio': 1.250012665923599, 'percentage_found': 100.0}
# {'file_name': '4d4a9bf4-fe98-43be-81dd-230fc0646d58.wav', 'compression_ratio': 1.25001265976625, 'percentage_found': 100.0}
# {'file_name': '8ee15ea8-4b91-491b-8a92-8135952e76d7.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '4ca7206c-3224-445e-8d2f-831f75d7c90a.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'c99bab57-3cb4-49ca-9042-03fd33a0aec9.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'ab06a9be-4fd4-4314-8b71-244f4dc96a7f.wav', 'compression_ratio': 1.2500126761991683, 'percentage_found': 100.0}
# {'file_name': '82e2daa4-66d7-425e-8bf1-bfda440babf4.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'def6eca8-d782-4fd2-9ebe-2e523dc0de7c.wav', 'compression_ratio': 1.2500126697749847, 'percentage_found': 100.0}
# {'file_name': '8d4d532f-7d52-435f-aa91-f7ef8b5ffa80.wav', 'compression_ratio': 1.2500126607920592, 'percentage_found': 100.0}
# {'file_name': '74c408e1-661a-45dd-a3fd-c4f808bea70d.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '61211a1e-99b8-4079-931a-a32845a5bf1d.wav', 'compression_ratio': 1.2500126636138915, 'percentage_found': 100.0}
# {'file_name': '46734a59-efbb-499b-b6cf-b41db37c9186.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'eb349384-55c1-4ab2-9a55-30e2acc86167.wav', 'compression_ratio': 1.25001266797738, 'percentage_found': 100.0}
# {'file_name': 'bdddb6a7-b2c6-4c67-8417-a5bbda5a1249.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'ffb6837e-be2b-474f-bdd0-3c9cd631f39d.wav', 'compression_ratio': 1.2500126648969585, 'percentage_found': 100.0}
# {'file_name': 'ea77a0a0-6149-4992-bc7b-eab537a31aef.wav', 'compression_ratio': 1.2500126656669233, 'percentage_found': 100.0}
# {'file_name': 'ad2a71e0-75c7-49f5-8122-fb7270e91158.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '212cc3ec-d36c-4437-accb-e75b03ea5849.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '0b4adf65-d666-4fa4-971f-6e7ed630d7fb.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '61095807-08cc-4b6a-aab4-6e1a2e558135.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'dab03e8b-a025-43bd-af70-51b221ff41c0.wav', 'compression_ratio': 1.250012666436982, 'percentage_found': 100.0}
# {'file_name': '242413fd-ddff-4a06-9b36-a373566e6e45.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '93dd0ad9-64be-4f7c-84e7-e189af478dab.wav', 'compression_ratio': 1.250012670545543, 'percentage_found': 100.0}
# {'file_name': '21d49517-5a31-43d1-bb5f-433b2951b7d1.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'fe52c559-1454-40d4-ad56-6f5e1d0af2d4.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '2c64a381-8d2c-416c-bc75-ed47ec9eeba3.wav', 'compression_ratio': 1.250012628048411, 'percentage_found': 100.0}
# {'file_name': 'f797ea2b-5b64-41a3-9c56-e994d4cf0674.wav', 'compression_ratio': 1.2500126587406073, 'percentage_found': 100.0}
# {'file_name': '184d8ddc-e6ea-46df-abe6-193f03d94e5e.wav', 'compression_ratio': 1.2500126285587279, 'percentage_found': 100.0}
# {'file_name': 'a68ef1cb-ddde-4e0c-ae91-11573bdb3701.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '7c27abad-0bd5-47d5-8d61-c0716d4cc87d.wav', 'compression_ratio': 1.2500126723438767, 'percentage_found': 100.0}
# {'file_name': '1c276f5f-44f9-4ef4-843c-972e4c0c1ee3.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '746a0398-8607-42ea-930a-761fd8b3fcf6.wav', 'compression_ratio': 1.250012656946132, 'percentage_found': 100.0}
# {'file_name': 'ea1348d5-fb1f-4416-83ca-e229ddc738cb.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '62406947-8f41-4790-9128-c792ab0cb6ce.wav', 'compression_ratio': 1.2500126618180345, 'percentage_found': 100.0}
# {'file_name': '02365fe0-4e01-4e82-a9c8-ab97389f2217.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '667b32ec-30bd-4bc2-8ffb-ab3c3a4fa4d1.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'daa68cb2-b5bd-42e2-a3a2-3bde258a3406.wav', 'compression_ratio': 1.2500126607920592, 'percentage_found': 100.0}
# {'file_name': 'c68e8c75-7434-45e2-a076-8fc7fe50a22b.wav', 'compression_ratio': 1.250012675942076, 'percentage_found': 100.0}
# {'file_name': 'b6bc60bf-686f-4103-a3ed-aaf2e888ee5a.wav', 'compression_ratio': 1.2500126564335183, 'percentage_found': 100.0}
# {'file_name': 'a7849205-2474-4a8d-9c6b-77181ff6e635.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '04154ce4-b699-4a1d-a4fb-7068e07c00fa.wav', 'compression_ratio': 1.2500126536148848, 'percentage_found': 100.0}
# {'file_name': '7d2e10a6-31b6-4d70-bfe3-d2627f1352e4.wav', 'compression_ratio': 1.250012666436982, 'percentage_found': 100.0}
# {'file_name': '7925f46f-51c3-482d-8537-e3b2e7ddd85e.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '37866662-764a-45d4-b3cf-d88efa70e5b3.wav', 'compression_ratio': 1.25001266797738, 'percentage_found': 100.0}
# {'file_name': '172741e6-a29e-45d4-81d0-e45d525fdeec.wav', 'compression_ratio': 1.25001265668982, 'percentage_found': 100.0}
# {'file_name': 'c9139beb-ef5c-4089-9ddd-6abd7fd0972b.wav', 'compression_ratio': 1.2500125504528203, 'percentage_found': 100.0}
# {'file_name': '92f3b248-d705-41d1-b46c-70f67bd71ae5.wav', 'compression_ratio': 1.2500126633573092, 'percentage_found': 100.0}
# {'file_name': '16ade36e-d993-4d65-8cfd-c5d94ceef5d3.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'd0e66872-fb66-41a3-a589-a374dfe01161.wav', 'compression_ratio': 1.2500126214180416, 'percentage_found': 100.0}
# {'file_name': '21b7260c-4054-4a67-983c-bb8c3c98fc98.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '11b6e1f9-70f4-41ec-9a22-d80b9d5894a2.wav', 'compression_ratio': 1.2500126600226869, 'percentage_found': 100.0}
# {'file_name': '31df8ceb-a246-4e1c-a979-c871494e103c.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '64030dcb-b007-4f0c-a957-76f5b5372c64.wav', 'compression_ratio': 1.2500125504528203, 'percentage_found': 100.0}
# {'file_name': '9e1b29d5-2b15-4f1c-856e-c223b3b3066c.wav', 'compression_ratio': 1.2500126265177074, 'percentage_found': 100.0}
# {'file_name': 'b5b8714f-6a0c-4ed0-a3bf-a95e2f48c0ee.wav', 'compression_ratio': 1.2500126628441761, 'percentage_found': 100.0}
# {'file_name': 'ef575387-3ce3-48fe-9002-4c9432e91503.wav', 'compression_ratio': 1.25001266797738, 'percentage_found': 100.0}
# {'file_name': '0ecaa518-44bb-472e-af0f-372321b2f05f.wav', 'compression_ratio': 1.250012665923599, 'percentage_found': 100.0}
# {'file_name': '9d3e4007-4faf-4eb7-9bfd-edb27251734d.wav', 'compression_ratio': 1.250012547177387, 'percentage_found': 100.0}
# {'file_name': '30179ac2-f5a7-436e-8393-651dcf8a5d7b.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '38fd9c77-fb75-4cd5-8f1b-c4ff26b86b28.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '37a896d0-6e9c-49cc-9eac-c203ed068617.wav', 'compression_ratio': 1.25001265976625, 'percentage_found': 100.0}
# {'file_name': '1c37fd0e-1c6b-4d84-9108-1adbf8ae3f91.wav', 'compression_ratio': 1.250012667720621, 'percentage_found': 100.0}
# {'file_name': '55c95e62-6ce1-459c-bf7e-057f40bb9dc9.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '6972b2fe-99a9-4a98-a746-d066515b8e9e.wav', 'compression_ratio': 1.2500126600226869, 'percentage_found': 100.0}
# {'file_name': '66b41ae6-05d6-4758-8646-1fc3e4face3e.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'b37571bb-bc46-436b-b6f5-f579260d73e0.wav', 'compression_ratio': 1.2500126643837004, 'percentage_found': 100.0}
# {'file_name': 'abe4ee6f-f523-4f78-9098-b5f8eb4a8117.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '4aa5c35c-b298-428d-8918-7ab8f48b0493.wav', 'compression_ratio': 1.2500126582278481, 'percentage_found': 100.0}
# {'file_name': '8e664a04-817f-44ec-9569-bbcb5a173b8c.wav', 'compression_ratio': 1.2500125827947897, 'percentage_found': 100.0}
# {'file_name': 'a71fe9f4-1f39-4a86-be66-afc135ebfed5.wav', 'compression_ratio': 1.2500126687477195, 'percentage_found': 100.0}
# {'file_name': '416c2b86-8d23-4d46-9fc8-12c736bca08e.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '02d7e5f2-e647-462f-883d-a0cb1daa5503.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '564cfa0a-4219-4bd4-8d92-ce59b3a70f11.wav', 'compression_ratio': 1.2500126610485374, 'percentage_found': 100.0}
# {'file_name': 'd657634f-4d93-410c-8a95-52e2da100a72.wav', 'compression_ratio': 1.25001265976625, 'percentage_found': 100.0}
# {'file_name': '2daf7e7e-c634-4fa8-9c13-3b47e055ad48.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '778cb5c5-b503-483b-a635-6cde49e0c257.wav', 'compression_ratio': 1.2500126697749847, 'percentage_found': 100.0}
# {'file_name': 'd7cedfb3-8eba-4b53-b453-7c9e22584dec.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'fb93325d-52cd-4ea5-a769-9fb09717b4db.wav', 'compression_ratio': 1.2500126646403242, 'percentage_found': 100.0}
# {'file_name': '40b8ccac-db4f-4aee-a21e-5eb767c9b9a8.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'd24add11-a9d6-4583-9f03-eedab99eaa7a.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': 'f1461d76-1c5b-4ceb-998a-c81a74ef0317.wav', 'compression_ratio': 1.250012666436982, 'percentage_found': 100.0}
# {'file_name': '16c6d8eb-d79e-4f4e-954a-f2f1c4110264.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# {'file_name': '383e5327-6c55-4265-a30e-059837163598.wav', 'compression_ratio': 1.25, 'percentage_found': 100.0}
# ...
# File: 048c9205-bada-4bed-b466-30cca0ac5a59.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: ae8c94f2-251f-4615-a78a-c4b498d0a06c.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: af7ffc61-3ffc-4c22-b7b8-1bcf17d516ae.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 6c7b12ed-6f6a-43ac-b7bf-08eb9bddef30.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 8df88da0-50c0-40c2-8e9f-46ae1685653e.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: f6bbd852-d3aa-49f2-8af5-dc7020910347.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 1e71f8d8-bae0-4970-929a-58e77df87103.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 1c6bf8b8-7bef-439d-ab17-cd338288e977.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 81635566-2449-485d-ac29-dc1117eb9af7.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 18bd387e-7dbb-45e1-98f7-a0fa5b980d61.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 71767ef9-97a4-4752-908b-f649d08f6973.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 8be1e5ac-9cab-472f-a0d5-f66849b7ec5e.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 39bb8054-e70c-48df-8b97-bda6f2c891e6.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 602dd674-c438-495d-83a7-23efaae6f8c0.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 7129eff4-1c85-43cb-a926-78dcbf3437e2.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: f5404fd5-4af5-4fee-b56e-19d3e66cbcc5.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: ec6f4824-6567-4600-a910-547c31f292dd.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 925d372a-5f9e-4932-bc7a-da7d573a16f1.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: ce419c78-9616-49fa-87e0-b64148aa12a6.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 89643052-2534-4c1d-9eee-f55867bedee7.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 0aefe960-43fd-41cc-97c8-bf9d2d64efd3.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 25f747d9-8619-4bac-9cdf-2e6979ae338b.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 4b3f685d-1f25-4004-9457-c992d2ffa647.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: e2445f04-1c49-4e5c-aa23-c67c6439f14d.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 59c3cf10-91ec-409b-9576-b106b58ad6bb.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 51846093-43b0-4873-ba1a-ee503f3bdb9d.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 51d333e5-823d-434d-b3bc-638aeed222b1.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 8dd8051b-94d0-4c73-9cf4-3447cbb0755d.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 57421962-30e8-4ed6-b839-a409e3f50c7b.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 3ca76236-cd0a-4745-a7b7-9274a70168e7.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 5fd335ea-1259-4895-a540-06258f0fb69a.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 8c46512e-54de-4e6c-a40f-1b23e52b796d.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 04d1c648-49c6-4b33-b290-3f829b9bf4f9.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: f0029013-a7b0-4c83-ab88-e7ff14f7728f.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 69b06303-d4fe-4768-b532-9edf3f1956dc.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 9876c7af-f8a0-4b8c-a80d-b2b7aa9dcd4b.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: cd19eeae-bf70-4492-a206-0b2eaeb4c1d2.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 3fd3d38c-15e5-4206-86f3-62fe49ef323d.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 08d069d4-366c-41aa-946b-eaa3eb8f9565.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 218db45e-3818-469d-8eeb-4c35e39f63c1.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 733aa94c-4ed1-432c-8f9d-f0bbf4569c78.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: ff970660-0ffd-461f-93de-379e95cd784a.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 1a971a8c-cb8d-48ef-aad2-f7258947726c.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 6f27b7c0-b35e-4d69-9534-607829224153.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: c34dae3b-a6cf-4fb0-8d1f-460d42b2ba7a.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: cdd0bd51-2684-44db-ad8d-f9bf37367292.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 6c6c6720-bd7c-4f0d-b6a5-2e0aef1c4a45.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 16fb787d-3d09-46fc-9560-ff82641112d2.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: e03b7ff5-569a-4b3f-a7db-f4a7188718fc.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 628ac62f-2d6c-4d3f-89c8-f2b207f4cd44.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 64252bd6-3d67-4e84-a3c9-8186516a8586.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: bc184a03-702d-4e20-a84f-947be81448f7.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: af2f8db9-b6aa-48ab-addb-572a592b3e5e.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: d8149feb-7159-4c5a-8bc2-881fbb185b97.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: a7e6978d-9259-4b52-bfc5-d881033f0d89.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: d637914e-b564-4f17-9df9-79b66125e0e3.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: b800deb5-00a6-4ef2-b99a-42359684367a.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 028a8e19-3e49-4fc0-a5df-5055bb98f1c7.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 443ae2ae-ce86-4a10-aba1-bc0bb51b39f3.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 2985450f-b117-4a49-adb1-73a7a0118505.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 5fd769b6-b7e4-4121-81ff-e42c45fb0648.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 5611ca15-4d92-4cef-8187-8b2db56521a2.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 773e20b9-ea85-4a99-8af8-f13cbcbf0914.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: cec06996-07de-4f7e-9914-d54bd547232b.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 00dc461c-a60a-4d74-bf87-de4208f224ee.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 6fb6e630-0bc6-4adf-9217-ec8b48123552.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 7682ac5c-1306-456e-b144-70b77b1cd415.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: bb90f5f0-d305-46e1-8c1d-d017d728883a.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: bbd01ca3-48df-41b9-a54f-a4d666db307e.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: ff07d2c2-51a1-49ec-85ab-80df95461ce5.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 846510e8-12c3-4b3e-a492-72fc6e067378.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 83b41ade-3f89-4ba4-ab38-655f1d1c8df7.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 5e5363b2-194e-433d-8165-e576b981873e.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 878825f7-20a2-4394-8c75-ff47f3fda9d3.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: e7ac9464-2da1-4037-b5cf-dfa58f891262.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 01f5f49e-287d-4734-be3a-863c10c0cf2e.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: b9d3fa13-5a79-4214-8bbe-8dea7a5ad8e7.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: d405f220-d24b-4332-9023-382c149531bd.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: c64a9a77-0a86-4108-9223-985d80602b22.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 209648c9-c6c6-4b87-b44b-20b29744da99.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 07c990a2-7775-428b-ad4b-3cf4a233d5f6.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: ca1df83a-d8c2-4c6f-b28b-d4b70b60f469.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 312b2c93-0838-412d-b408-63c9cf74adf9.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 2d8b941a-3ff9-41eb-917c-10fa16ebffee.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 70273408-6898-4ce0-891a-d6fa78db2d1d.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 4630b95e-f8d9-4842-b088-ccde4d2509eb.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 49c14ec7-9402-4d5a-898c-e133fe1719a0.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 629e3b5b-3829-4583-8e1c-d84825ca08b2.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 1b7285f1-2768-4979-93c1-045bb6236611.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: cdd3ad00-b819-4a86-905a-ec7541a65b56.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 1db81462-4597-4cee-846b-b5cc0940bcf9.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 234d006b-0101-4228-95a4-7540525d2ebc.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 055f3d08-6691-4eb8-8612-4140f654426f.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: b4a354ca-8194-4459-b711-0fd099b117e8.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: c88a7cf8-012b-4f2d-bafe-19f638b72ad1.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 032a5ecb-f35c-4af5-964c-8f42cbcd9a41.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 0052503c-2849-4f41-ab51-db382103690c.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: eff381aa-1187-4d22-a10f-d59204d1e5cf.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 5540ae6d-b1c6-4c62-a03d-20ede2558afc.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 91b850dc-5923-44d4-9f9a-051fc87cec00.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: d21a5147-a3e6-45bd-842c-6bee89552504.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 01671c57-4584-40cd-998d-c49b211e386c.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: d4ab6765-2ada-45f7-9643-bdaa24778760.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: ddedbafa-5bc9-4a93-8a46-ff8eeddaa65c.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 7b95b0c0-9610-422f-835c-8c9f972f7462.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 9867d779-5da9-4c46-94b9-bf29baf269d9.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: da6c3a3b-db48-4c13-884c-3f33f5d2b964.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 578f64cd-9855-4a4f-bd78-3bf446b64391.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 3960fcd4-393c-47c3-8935-892c1b0da34d.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: ebbff300-a2bb-4b43-bbab-18a17049a09d.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: ad312ccb-dd19-44ad-bd9b-e4df378ce355.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 6228b2ef-c8c1-4a3a-a57c-d5dbbed6d4a1.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: e48befb9-a32a-4bcc-af7a-2cd62d76888c.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 3b66780e-d642-4e53-9a6f-85864ffb1aca.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: ed27ab15-7e60-4151-bd2c-380f376b9a75.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 6631cc7c-af05-450e-880c-f7882760085b.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: fd4a6298-5411-42b9-ab2a-8dbc26258036.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: fd979802-467f-4efb-8bb1-cd72345fbdb0.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: ca2a0773-c1ee-462a-a124-7be7fccc9101.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: a2146e3f-ec0d-44d9-bb0b-9ce727870698.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: d850634a-220c-4f1f-a4b2-2f3c494b714c.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: b0ad441a-6a1f-4a23-8847-246620ac1b88.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 74845371-43e3-4473-ae04-b3a7fe95648e.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: cb2fb833-e2e0-4321-a197-1434e94003bb.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 7bcd4cdc-36dd-4847-b946-164c9bebf3b2.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: d1a71bce-a021-43c0-8177-e3491a91c774.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: c01dec29-9511-443a-8135-9ec070806211.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: e9fc3234-82d1-47a4-8a51-a5497769f14b.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 38007d3b-bf50-4e44-98f8-3c1afbfaf868.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 3a791210-ecd6-40bd-8db1-c4b2e45d8669.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: c1d8e934-fc5c-4d2d-9ba2-47b9fe395fee.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 0befa6a5-0c9b-44c6-93b8-eb6678045480.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: e350d041-d471-4347-aa47-9c2573daeb0f.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: d6df50ca-53b3-4351-840c-cd654a81cdea.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 37cee1c9-1b71-4e99-9315-5f38e99e1485.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 7c808071-6984-4421-b073-a515000f58a1.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: eeb713ca-4b07-4895-8824-f2a182cfbc0b.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 8b694768-831c-430f-a32a-80acf9d7baf6.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 8a16c0c6-77e3-4d09-b462-6650c5ba270b.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: e4903585-b2b2-422f-a028-c9f5c2b31f16.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: cff25bde-af14-4b61-a9d0-b1a335d4e2b8.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 5b5da578-855f-4866-88b7-70ddcbe4f2a8.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: df31b6c3-714a-4c1d-8c11-1c68838540b0.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 0e483848-ab61-4155-9a13-ed7668b2b956.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 5cb343b2-dfa2-42f8-82ea-948147a63020.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 2d910bad-e8ae-4ef5-a080-bf7efde42adf.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: ac61ae46-6e4b-4e41-82e6-8bbb61a2b2c7.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: c438ff81-e776-4dd6-9df0-03c84a9ed3c6.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 3745a64f-9be1-41fb-975d-9c7c2baa0947.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: a62f6dfd-09a5-48cb-98be-033b79d7e67c.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 25c532c4-1494-47a4-901e-5fcea3492038.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: abdcefa3-12a1-4e7e-97b3-e2d9e60279be.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: f309328e-84bd-48ff-a324-230d14e0f928.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 34ae1187-4f68-4844-a157-a4693c16177d.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: fd8f60dc-a9bf-48b6-b506-d4a1bdaf3321.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: ed6f33b5-8a75-4b1c-8651-9101eb077176.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 8e8e10f3-37b4-493b-994b-5d44048dc2b6.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: f41b2956-e346-44c8-b28c-0db5c678d633.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 87a15832-9532-48a9-8b87-0c7ec8bf2d6a.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: efa9d79b-c7cc-464f-a499-ed010b6edfe4.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: e4fe5ed6-60ce-402f-b799-185782f11bf4.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: b31e55c6-9d09-4074-8efb-56d898aa198d.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: 5a8e8ab0-27ed-48b9-8c27-16a371c74a3f.wav, Compression Ratio: 1.25, Segments Found: 100.00%
# File: b2d2d35b-bac6-48ae-8c45-884cbef0f6b9.wav, Compression Ratio: 1.25, Segments Found: 100.00%
